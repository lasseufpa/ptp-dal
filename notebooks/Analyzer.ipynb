# %% [markdown]
# # Analyzer
#
# This notebook is a wrapper to the `analyze.py` script. It can be used as the starting point of an analysis. All you have to do is customize some parameters (such as the dataset file name), run the common processing steps imported from the `analyze.py` script, and then work on the specific points of interest using the dataset within variable `ds`.

# %%
import sys, os
sys.path.append(os.path.abspath('../'))
import analyze
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
args = analyze.parse_args()

# %%
## Customize some parameters
args.file = "serial-20200726-230128-comp"
args.verbose = 4

# %%
analyze.setup(args)

# %%
ds = analyze.read_dataset(args)

# %%
analyze.process(ds, args)
# Out:
# Tuned window lengths:
#                   ls: 1024
#       sample-average: 8192
#          sample-ewma: 8192
#        sample-median: 8192
#           sample-min: 256
#           sample-max: 4096
#          sample-mode: 8192

# %%
analyze.analyze(ds, args, save=False)
# Out:
# Setup:
# {
#     "calibration": false,
#     "calibration_duration": 0,
#     "departure_ctrl": false,
#     "departure_gap": {},
#     "duration": "0:59:59.992309",
#     "fh_traffic": null,
#     "hops": {
#         "rru1": 4,
#         "rru2": 4
#     },
#     "n_exchanges": 460800,
#     "n_rru_ptp": 2,
#     "oscillator": "xo",
#     "pipelines": {
#         "bbu": "3433",
#         "rru": "3433"
#     },
#     "ptp_unicast": false,
#     "start_time": "2020-07-26 22:57:51",
#     "sync_period": 0.0078125,
#     "sync_rate": 128,
#     "tstamp_latency_corr": {
#         "bbu": {
#             "rx": 80,
#             "tx": 80
#         },
#         "rru1": {
#             "rx": 80,
#             "tx": 80
#         },
#         "rru2": {
#             "rx": 80,
#             "tx": 80
#         }
#     }
# }
# Checking sequenceIDs: OK (no gaps)
# DL FH delay for rru1: best-case: 16.6400 us worst-case: 17.5600 us
# UL FH delay for rru1: best-case: 16.6400 us worst-case: 17.5600 us
# ...
